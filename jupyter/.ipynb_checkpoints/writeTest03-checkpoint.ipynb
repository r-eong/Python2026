# %%
import pandas as pd

# 공공데이터 포털에서 다운로드 받은 bike02.csv 파일 읽는 방법
df = pd.read_csv('greenData/bike02.csv', encoding= 'cp949')

# %%
# CSV 파일을 pandas로 읽는다.
# 상위10개출력한다.
# 대여건수가1000 이상인데이터만추출
# 대여건수기준내림차순정렬
# 전체대여건수합계구하기
# 평균대여건수구하기
# 가장대여건수가많은날짜찾기
